# %%
import pandas as pd
import numpy as np
import requests
import json
import time
import math
import os
import boto3
from datetime import datetime, timezone

s3_client = boto3.client("s3",
    aws_access_key_id = os.getenv('ACCESS_KEY'),
    aws_secret_access_key = os.getenv('SECRET'))

LOCAL_FILE_SYS = "/tmp/"
S3_BUCKET = "testbucketdevynduvall"  # please replace with your bucket name
CHUNK_SIZE = 200  # determined based on API, memory constraints, experimentation

google_key = 'AIzaSyCTXCSpjX0RJZC-L6xF97_tWq1NkLKXFZg'

def get_file_name(export_type):
    dt_now = datetime.now(tz=timezone.utc)
    file_name = (
        export_type
        + "."
        + dt_now.strftime("%Y-%m-%d")

        + ".csv"
    )
    return file_name

# Gets the file from s3
def get_all_rental_data(key):
    os.chdir(LOCAL_FILE_SYS)
    s3_client.download_file(S3_BUCKET, str("Rental/" + key), str(LOCAL_FILE_SYS + key))
    df_rental = pd.read_csv(LOCAL_FILE_SYS + key)
    df_rental = 
    return df_rental

# Queries the Google Place API based upon the rental data to search for all restaurants 
# around the rental properties returns the data frame
def restaurant_around_rental(rental):
    
    df_all = pd.DataFrame()
                                                 
    for index, row in rental.iterrows():
        location = str(row['lat']) + "," + str(row['lon'])
        radius = 500
        type = 'restaurant'
    
        url = f"https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={location}&radius={radius}&type={type}&key={google_key}"
    
        # make the request
        response = requests.get(url)

        # extract the results
        json_results = response.json()
        
        df_results = pd.json_normalize(data=json_results['results'])
        
        df_results['property_id'] = row['property_id']
    
        df_all = pd.concat([df_all, df_results], ignore_index=True)
    
    return df_all


def upload_to_aws(df, key):
    
    df.to_csv(str(LOCAL_FILE_SYS + key))
    
    s3_client.upload_file(str(LOCAL_FILE_SYS + key), S3_BUCKET, str("Rental_Restaurant/" + key))


def start(event, context):
    key_rental = get_file_name("Rental")
    key_rest = get_file_name("Rental_Restaurant")
    
    df_rent = get_all_rental_data(key_rental)

    df_restaurant = restaurant_around_rental(df_rent)
    
    # write_restaurant_data(df_rent, key_rest)
    
    upload_to_aws(df_restaurant, key_rest)
    
    return {"status":200}

# %%
import json

# Open the GeoJSON file for reading
with open('Shop-Export_7e21acdf-a06e-41b7-9c40-705f6215c44f_GeoJSON.geojson', 'r') as geojson_file:
    # Load the GeoJSON data
    data = json.load(geojson_file)

# Open the JSON file for writing
with open('output.json', 'w') as json_file:
    # Write the JSON data to the file
    json.dump(data, json_file)

# %%
data
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3109344, 47.7323365]},
#    'properties': {'osm_id': 2462453201,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Skillz Hair Studio'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.311105, 47.7323344]},
#    'properties': {'osm_id': 2462453192,
#     'beds': None,
#     'amenity': None,
#     'shop': 'bed',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Mattress By Appointment'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3140837, 47.7316675]},
#    'properties': {'osm_id': 10019054823,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Sa 09:30-17:30',
#     'name': 'Executive Estates Leasing Office'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3007551, 47.7113705]},
#    'properties': {'osm_id': 810668268,
#     'beds': None,
#     'amenity': None,
#     'shop': 'car_repair',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Pierre Chevrolet'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3002582, 47.7099298]},
#    'properties': {'osm_id': 810792546,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Manna Teriyaki'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3001777, 47.7100327]},
#    'properties': {'osm_id': 810792928,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Luciano's Pizza"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3001481, 47.7100996]},
#    'properties': {'osm_id': 810825379,
#     'beds': None,
#     'amenity': None,
#     'shop': 'tattoo',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': '"by appointment"',
#     'name': 'White Lotus Tattoo'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3001136, 47.7101768]},
#    'properties': {'osm_id': 810825381,
#     'beds': None,
#     'amenity': None,
#     'shop': 'copyshop',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Print Fusion'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.30127, 47.7038485]},
#    'properties': {'osm_id': 2984815342,
#     'beds': None,
#     'amenity': None,
#     'shop': 'erotic',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Video Videos'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3011828, 47.7041807]},
#    'properties': {'osm_id': 9949611336,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 09:00-17:00',
#     'name': 'Epic Cafe'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3006445, 47.7095857]},
#    'properties': {'osm_id': 9950198951,
#     'beds': None,
#     'amenity': None,
#     'shop': 'massage',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Su 10:00-22:00',
#     'name': 'Laurel Spa'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.176124, 47.7613573]},
#    'properties': {'osm_id': 5585698831,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Taco Del Mar'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1876787, 47.7608169]},
#    'properties': {'osm_id': 698418512,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'viewpoint',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1762446, 47.7613596]},
#    'properties': {'osm_id': 5585698832,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Starbucks'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1826679, 47.7759868]},
#    'properties': {'osm_id': 11161046991,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 06:45-15:30',
#     'name': "Lori's Deli & Espresso"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1834304, 47.762558]},
#    'properties': {'osm_id': 6515505692,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Tethers Unlimited'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1895632, 47.7613106]},
#    'properties': {'osm_id': 7530675785,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': "Beavers' and Climate Change"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1897643, 47.7770655]},
#    'properties': {'osm_id': 356552164,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Northshore School District - Special Services'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1913748, 47.7678219]},
#    'properties': {'osm_id': 6377020086,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'The Villas at Beardslee Crossing Leasing Office'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1914081, 47.7663726]},
#    'properties': {'osm_id': 6377019962,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'UW Bothell Chancellors Office'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1913653, 47.7667858]},
#    'properties': {'osm_id': 6377019956,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Sothebys'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1914378, 47.7665958]},
#    'properties': {'osm_id': 6377019958,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Sushi Chinoise'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1912487, 47.7666128]},
#    'properties': {'osm_id': 6377019960,
#     'beds': None,
#     'amenity': None,
#     'shop': 'clothes',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Marlowe Boutique'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1888296, 47.7601386]},
#    'properties': {'osm_id': 7530658183,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': 'Transportation: Impact on our River'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1891797, 47.7789314]},
#    'properties': {'osm_id': 5782063653,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Panasonic'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1887933, 47.7787922]},
#    'properties': {'osm_id': 2296302464,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Russell's Restaurant & Loft"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.190054, 47.7769501]},
#    'properties': {'osm_id': 356552206,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Northshore School District Office'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1896737, 47.7624497]},
#    'properties': {'osm_id': 10065035174,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': 'Our Urban Watershed'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.153473, 47.7569897]},
#    'properties': {'osm_id': 5778174553,
#     'beds': None,
#     'amenity': None,
#     'shop': 'mobile_phone',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Cricket Wireless'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1542797, 47.7566761]},
#    'properties': {'osm_id': 3797475951,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Qdoba'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1533751, 47.756382]},
#    'properties': {'osm_id': 710896934,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Teddy's Bigger Burgers"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1544543, 47.754092]},
#    'properties': {'osm_id': 6371005777,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Allstate'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1544502, 47.7539012]},
#    'properties': {'osm_id': 6371005780,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Sense of Style'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.153605, 47.75484]},
#    'properties': {'osm_id': 293833085,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Taco Time'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1534833, 47.757197]},
#    'properties': {'osm_id': 3797475949,
#     'beds': None,
#     'amenity': None,
#     'shop': 'interior_decoration',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'World Market'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1512982, 47.7554229]},
#    'properties': {'osm_id': 3157335396,
#     'beds': None,
#     'amenity': None,
#     'shop': 'gift',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Hallmark'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1506862, 47.7550435]},
#    'properties': {'osm_id': 3157335392,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'HairMasters'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1505676, 47.7550378]},
#    'properties': {'osm_id': 3157335393,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Papa Murphy's"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.148926, 47.7551636]},
#    'properties': {'osm_id': 1733689124,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Subway'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.15145, 47.7548908]},
#    'properties': {'osm_id': 3157335384,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'H&R Block'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.14894, 47.7547926]},
#    'properties': {'osm_id': 3157265154,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Matsu Teriyaki'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1497293, 47.7542801]},
#    'properties': {'osm_id': 7126371278,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Hopheads Taproom'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1534963, 47.7568301]},
#    'properties': {'osm_id': 3797475941,
#     'beds': None,
#     'amenity': None,
#     'shop': 'craft',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Aaron Brothers Art And Framing'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1533778, 47.7561838]},
#    'properties': {'osm_id': 6371006485,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Sport Clips'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1534478, 47.7561924]},
#    'properties': {'osm_id': 6371005784,
#     'beds': None,
#     'amenity': None,
#     'shop': 'beauty',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Dep Nails and Spa'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.154303, 47.7566245]},
#    'properties': {'osm_id': 3797475943,
#     'beds': None,
#     'amenity': None,
#     'shop': 'mobile_phone',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Verizon'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1532779, 47.7561959]},
#    'properties': {'osm_id': 6371006486,
#     'beds': None,
#     'amenity': None,
#     'shop': 'travel_agency',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Cruise Holidays Woodinville'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1544535, 47.7539645]},
#    'properties': {'osm_id': 6371005779,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Chop It Up'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1537149, 47.7535957]},
#    'properties': {'osm_id': 7399307985,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Jersey Mike's Subs"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1537166, 47.7538157]},
#    'properties': {'osm_id': 7399297381,
#     'beds': None,
#     'amenity': None,
#     'shop': 'dry_cleaning',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Jubilee Cleaners'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1537519, 47.7582139]},
#    'properties': {'osm_id': 3797475912,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Regis Salon'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1538742, 47.7581615]},
#    'properties': {'osm_id': 3797475928,
#     'beds': None,
#     'amenity': None,
#     'shop': 'mobile_phone',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Sprint'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1534894, 47.7583383]},
#    'properties': {'osm_id': 3797475888,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'IRG Physical Therapy'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1510762, 47.7558453]},
#    'properties': {'osm_id': 3157335389,
#     'beds': None,
#     'amenity': None,
#     'shop': 'tobacco',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Smoke Shop'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1511942, 47.7558438]},
#    'properties': {'osm_id': 3157335391,
#     'beds': None,
#     'amenity': None,
#     'shop': 'yes',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Nature's Remedy"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1514194, 47.7557597]},
#    'properties': {'osm_id': 3157335381,
#     'beds': None,
#     'amenity': None,
#     'shop': 'beauty',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Nails 4U'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1513331, 47.7555144]},
#    'properties': {'osm_id': 3157335379,
#     'beds': None,
#     'amenity': None,
#     'shop': 'medical_supply',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'MSI Medical Supply'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1508777, 47.7558219]},
#    'properties': {'osm_id': 3157335387,
#     'beds': None,
#     'amenity': None,
#     'shop': 'variety_store',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Dollar Tree'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.150631, 47.7558252]},
#    'properties': {'osm_id': 3157335385,
#     'beds': None,
#     'amenity': None,
#     'shop': 'second_hand',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Value Village'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1509171, 47.7550154]},
#    'properties': {'osm_id': 9648930887,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Woodinville Cafe'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1489345, 47.7549002]},
#    'properties': {'osm_id': 3157265150,
#     'beds': None,
#     'amenity': None,
#     'shop': 'beauty',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Bonjour Nails-Spa'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.148937, 47.7547455]},
#    'properties': {'osm_id': 3157265131,
#     'beds': None,
#     'amenity': None,
#     'shop': 'pet',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'The Whole Pet Shop!'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.149732, 47.7543703]},
#    'properties': {'osm_id': 7126371277,
#     'beds': None,
#     'amenity': None,
#     'shop': 'mobile_phone',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'T-Mobile'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1489237, 47.7541722]},
#    'properties': {'osm_id': 3157265145,
#     'beds': None,
#     'amenity': None,
#     'shop': 'massage',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Massage Envy'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1489052, 47.7539275]},
#    'properties': {'osm_id': 1733689121,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Chan's Place"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.156086, 47.7372174]},
#    'properties': {'osm_id': 7042488885,
#     'beds': None,
#     'amenity': 'bar',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Northwest Spirits'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.155963, 47.7372081]},
#    'properties': {'osm_id': 7042488387,
#     'beds': None,
#     'amenity': None,
#     'shop': 'wine',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Cascade Cliffs Vineyard & Winery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.149421, 47.7345392]},
#    'properties': {'osm_id': 303627675,
#     'beds': None,
#     'amenity': None,
#     'shop': 'wine',
#     'rooms': None,
#     'tourism': 'wine_cellar',
#     'opening_hours': None,
#     'name': 'DeLille Cellars'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.154654, 47.7379857]},
#    'properties': {'osm_id': 1226375622,
#     'beds': None,
#     'amenity': None,
#     'shop': 'wine',
#     'rooms': None,
#     'tourism': 'attraction',
#     'opening_hours': None,
#     'name': 'Woodhouse Winery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.156504, 47.7455185]},
#    'properties': {'osm_id': 11050125685,
#     'beds': None,
#     'amenity': None,
#     'shop': 'spices',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Th,Su off; Fr-Sa 10:00-14:00',
#     'name': 'Sammamish Valley Herb Farm'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.152055, 47.7534059]},
#    'properties': {'osm_id': 1403865493,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo,We-Su 11:00-20:00; Tu 11:00-18:00',
#     'name': 'Bobae Coffee and Tea'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1522401, 47.7534042]},
#    'properties': {'osm_id': 3157265140,
#     'beds': None,
#     'amenity': None,
#     'shop': 'fashion_accessories',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "claire's"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1503687, 47.7550485]},
#    'properties': {'osm_id': 3157335388,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'One Bite Cafe'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.153714, 47.7535378]},
#    'properties': {'osm_id': 5830070233,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Su 11:00-21:00',
#     'name': "Ezell's Famous Chicken"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.0410737, 47.7136639]},
#    'properties': {'osm_id': 360968024,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.0469213, 47.7164775]},
#    'properties': {'osm_id': 356523282,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3681843, 47.7115632]},
#    'properties': {'osm_id': 9467030444,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3741601, 47.7135238]},
#    'properties': {'osm_id': 67390356,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3750919, 47.7144826]},
#    'properties': {'osm_id': 3601592225,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3772015, 47.7130346]},
#    'properties': {'osm_id': 1728414827,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3789734, 47.7120487]},
#    'properties': {'osm_id': 9039262286,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': 'What is a wetland?'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3775069, 47.71174]},
#    'properties': {'osm_id': 9039262281,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': 'Buffer Power!'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3778392, 47.7117834]},
#    'properties': {'osm_id': 9039262282,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': 'Salmon are a Linchpin Species'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3784316, 47.7117793]},
#    'properties': {'osm_id': 9039262280,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': 'Look and listen… but please do not get into the creek!'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3789219, 47.7125624]},
#    'properties': {'osm_id': 9061146490,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': 'Share the Shore with Harbor Seals'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1114983, 47.6721442]},
#    'properties': {'osm_id': 2626111432,
#     'beds': None,
#     'amenity': None,
#     'shop': 'cosmetics',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Ulta Beauty'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1116403, 47.6714096]},
#    'properties': {'osm_id': 2627343711,
#     'beds': None,
#     'amenity': None,
#     'shop': 'video_games',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Sa 10:00-21:00;Su 11:00-18:00',
#     'name': 'GameStop'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.110978, 47.6726515]},
#    'properties': {'osm_id': 1196854007,
#     'beds': None,
#     'amenity': None,
#     'shop': 'florist',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Bear Creek Floral & Gifts'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.110912, 47.6726517]},
#    'properties': {'osm_id': 1197661599,
#     'beds': None,
#     'amenity': None,
#     'shop': 'dry_cleaning',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Fabricare Cleaners'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.11066, 47.6726525]},
#    'properties': {'osm_id': 418996958,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Starbucks'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1099678, 47.6726114]},
#    'properties': {'osm_id': 1243260800,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Yummy Teriyaki'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.109982, 47.6712571]},
#    'properties': {'osm_id': 2633074372,
#     'beds': None,
#     'amenity': None,
#     'shop': 'mobile_phone',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Sa 10:00-19:00; Su 11:00-18:00',
#     'name': 'Verizon'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1118977, 47.6719582]},
#    'properties': {'osm_id': 1257414155,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Su-Th 11:00-22:00; Fr-Sa 11:00-23:00',
#     'name': 'Agave Cocina & Cantina'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1172839, 47.6723382]},
#    'properties': {'osm_id': 9726087300,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Penny Nicholls Salon'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1183251, 47.6725626]},
#    'properties': {'osm_id': 4353378480,
#     'beds': None,
#     'amenity': 'post_office',
#     'shop': 'copyshop',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'The UPS Store'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1157467, 47.6726731]},
#    'properties': {'osm_id': 4158630489,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'artwork',
#     'opening_hours': None,
#     'name': 'Aurora And Diane'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1171928, 47.6729619]},
#    'properties': {'osm_id': 4158630596,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "DJ's Hair Designs"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1126522, 47.6730002]},
#    'properties': {'osm_id': 4853787337,
#     'beds': None,
#     'amenity': None,
#     'shop': 'convenience',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'La Superior - Redmond Mart'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1146503, 47.6715937]},
#    'properties': {'osm_id': 4350388493,
#     'beds': None,
#     'amenity': None,
#     'shop': 'convenience',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Express Mart'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1167138, 47.6719336]},
#    'properties': {'osm_id': 4353378431,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Hopelink'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1171885, 47.6719255]},
#    'properties': {'osm_id': 4353378444,
#     'beds': None,
#     'amenity': None,
#     'shop': 'pet',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Motley Zoo'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1177504, 47.6720149]},
#    'properties': {'osm_id': 4353378483,
#     'beds': None,
#     'amenity': None,
#     'shop': 'wine',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'World of Wines'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1200134, 47.6746306]},
#    'properties': {'osm_id': 4353378442,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Mirage Hair Design'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.117272, 47.6736824]},
#    'properties': {'osm_id': 4353378433,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Inlife Clinic'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1170017, 47.6723586]},
#    'properties': {'osm_id': 2642174721,
#     'beds': None,
#     'amenity': None,
#     'shop': 'bakery',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Sa 06:00-14:00',
#     'name': 'Kringles Bakery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1174939, 47.672437]},
#    'properties': {'osm_id': 9726087243,
#     'beds': None,
#     'amenity': None,
#     'shop': 'beauty',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'the Lash & Wax boutique'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.118533, 47.6727001]},
#    'properties': {'osm_id': 9726088934,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'State Farm'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.118716, 47.6725961]},
#    'properties': {'osm_id': 2626186131,
#     'beds': None,
#     'amenity': None,
#     'shop': 'musical_instrument',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Music & Arts'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1172873, 47.6722971]},
#    'properties': {'osm_id': 4164273089,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Emerald City Smoothie'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1127635, 47.6730065]},
#    'properties': {'osm_id': 4853787343,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Sunny Teriyaki'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1137086, 47.6712239]},
#    'properties': {'osm_id': 418778905,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Th 10:30-22:30; Fr,Sa 10:30-23:00; Su 11:00-21:30',
#     'name': 'Dairy Queen'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1180539, 47.6723801]},
#    'properties': {'osm_id': 4353378414,
#     'beds': None,
#     'amenity': None,
#     'shop': 'costume',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Sa 11:00-19:00; PH off',
#     'name': 'A Masquerade Costume'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.119063, 47.6712481]},
#    'properties': {'osm_id': 4792797629,
#     'beds': None,
#     'amenity': None,
#     'shop': 'pet',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Sa 10:00-20:00; Su 11:00-19:00',
#     'name': 'Eastside Dog and Cats Too'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3253918, 47.6811989]},
#    'properties': {'osm_id': 2463139535,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'UBuildIt'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.324803, 47.6802354]},
#    'properties': {'osm_id': 2463139502,
#     'beds': None,
#     'amenity': 'bar',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Little Red Hen'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3253672, 47.680272]},
#    'properties': {'osm_id': 2463139500,
#     'beds': None,
#     'amenity': 'bar',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Shelter'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3242231, 47.6807256]},
#    'properties': {'osm_id': 2463138842,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Olympic Distributors, Inc.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.323575, 47.6806125]},
#    'properties': {'osm_id': 3746533327,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Green Lake Village Leasing Office'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3237247, 47.6802358]},
#    'properties': {'osm_id': 4218064604,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Kitanda'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.324391, 47.6799437]},
#    'properties': {'osm_id': 9904241734,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Fringe'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3256882, 47.6804464]},
#    'properties': {'osm_id': 2463139506,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Greenlake Grill'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3248217, 47.6809727]},
#    'properties': {'osm_id': 2463139528,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Luu’s'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3258941, 47.6806895]},
#    'properties': {'osm_id': 3708905821,
#     'beds': None,
#     'amenity': None,
#     'shop': 'clothes',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 10:00-19:00; Sa 10:00-18:00; Su 10:00-17:00',
#     'name': "Super Jock 'n Jill"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3248304, 47.6803423]},
#    'properties': {'osm_id': 2463139504,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Da Long Yi Hot Pot'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3249965, 47.6783462]},
#    'properties': {'osm_id': 3311161064,
#     'beds': None,
#     'amenity': None,
#     'shop': 'dry_cleaning',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 08:00-18:00; Sa 09:00-17:00; Su off',
#     'name': 'Ultra Cleaners'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3251274, 47.678306]},
#    'properties': {'osm_id': 3311160767,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 11:30-21:30; Sa 12:00-22:00; Su 12:00-21:30',
#     'name': 'Thai Ocean'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3253918, 47.6785256]},
#    'properties': {'osm_id': 11160050274,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 10:00-18:00; Sa 10:00-17:00; Su off',
#     'name': 'Circa Greenlake Leasing Office'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3010253, 47.6762002]},
#    'properties': {'osm_id': 3348903128,
#     'beds': None,
#     'amenity': None,
#     'shop': 'car_repair',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Salmons Auto Center'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.303481, 47.675894]},
#    'properties': {'osm_id': 2462325118,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Dao's Hair Cuts"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1220839, 47.6743242]},
#    'properties': {'osm_id': 5872680158,
#     'beds': None,
#     'amenity': None,
#     'shop': 'books',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Fr 10:00-18:00; Tu-Th,Sa 10:00-16:00',
#     'name': "McDonald's Book Exchange"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.144064, 47.6835259]},
#    'properties': {'osm_id': 2106231828,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Subway'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.126433, 47.6808314]},
#    'properties': {'osm_id': 1055365415,
#     'beds': None,
#     'amenity': None,
#     'shop': 'supermarket',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Su 05:00-24:00',
#     'name': 'QFC'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1182169, 47.672565]},
#    'properties': {'osm_id': 4353378597,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Headquarters'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1279958, 47.6792267]},
#    'properties': {'osm_id': 10815504177,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'artwork',
#     'opening_hours': None,
#     'name': 'Salmon Rising'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1246041, 47.6736412]},
#    'properties': {'osm_id': 4350388492,
#     'beds': None,
#     'amenity': None,
#     'shop': 'bakery',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Su 07:00-19:00',
#     'name': "Hoffman's"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1221418, 47.6733836]},
#    'properties': {'osm_id': 4353378454,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Prime Steakhouse'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1117912, 47.6713719]},
#    'properties': {'osm_id': 2627336275,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Five Guys'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.120475, 47.6737906]},
#    'properties': {'osm_id': 11028360363,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Farine Bakery & Cafe'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1311395, 47.6747473]},
#    'properties': {'osm_id': 11054982138,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1200345, 47.6697211]},
#    'properties': {'osm_id': 2626130765,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Matts' Rotisserie & Oyster Lounge"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1194, 47.6703259]},
#    'properties': {'osm_id': 4562997506,
#     'beds': None,
#     'amenity': None,
#     'shop': 'clothes',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'American Eagle Outfitters'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1168307, 47.6701435]},
#    'properties': {'osm_id': 10874962806,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Sa 11:00-14:30,16:30-20:00; Su off',
#     'name': 'DAK Korean Fried Chicken'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1400272, 47.6836113]},
#    'properties': {'osm_id': 10713154024,
#     'beds': None,
#     'amenity': None,
#     'shop': 'car',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Columbia Valley Luxury Cars'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.110783, 47.6701837]},
#    'properties': {'osm_id': 2623010946,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 10:00-21:00',
#     'name': "Jersey Mike's Subs"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1270057, 47.6746005]},
#    'properties': {'osm_id': 2624149206,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Su 11:00-22:00',
#     'name': 'Zeeks Pizza - Redmond'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1230835, 47.681548]},
#    'properties': {'osm_id': 2834354822,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Zoëyogurt'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1200336, 47.6700669]},
#    'properties': {'osm_id': 3731225641,
#     'beds': None,
#     'amenity': None,
#     'shop': 'ice_cream',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Red Mango'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2013576, 47.6770254]},
#    'properties': {'osm_id': 1234318474,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'picnic_site',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.177435, 47.6795362]},
#    'properties': {'osm_id': 3339112096,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Yang's Dumpling House"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2029744, 47.6756657]},
#    'properties': {'osm_id': 4113069128,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'artwork',
#     'opening_hours': None,
#     'name': 'Carousel'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.198838, 47.6778984]},
#    'properties': {'osm_id': 10767407556,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'gallery',
#     'opening_hours': None,
#     'name': 'Ryan James'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2009458, 47.6759478]},
#    'properties': {'osm_id': 10767407558,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 10:00-16:00',
#     'name': 'Kirkland Performance Center Administrative Offices'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1876001, 47.6784036]},
#    'properties': {'osm_id': 11050125671,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Pace'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.291367, 47.7059]},
#    'properties': {'osm_id': 3211770326,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'artwork',
#     'opening_hours': None,
#     'name': 'Schema'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.291333, 47.70585]},
#    'properties': {'osm_id': 3211770324,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'artwork',
#     'opening_hours': None,
#     'name': 'Fish Children'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2891094, 47.7052849]},
#    'properties': {'osm_id': 10938097749,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2649134, 47.6881653]},
# ...
#    'properties': {'osm_id': 3430283347,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Fr 07:00-22:00; Sa 08:00-22:00; Su 08:00-20:00',
#     'name': 'Honey Bear Bakery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.280321, 47.754676]},
#    'properties': {'osm_id': 6923696065,
#     'beds': None,
#     'amenity': None,
#     'shop': 'sewing',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Needles and Hooks'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2779664, 47.7539369]},
#    'properties': {'osm_id': 9925253585,
#     'beds': None,
#     'amenity': None,
#     'shop': 'bicycle',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Th-Su 09:00-17:00',
#     'name': 'Amped Adventure'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3313381, 47.7406976]},
#    'properties': {'osm_id': 4281322784,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'picnic_site',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3304645, 47.7399724]},
#    'properties': {'osm_id': 3729793125,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'picnic_site',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.32357, 47.7483904]},
#    'properties': {'osm_id': 3192428578,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Cafe Aroma'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3229034, 47.7487517]},
#    'properties': {'osm_id': 9217332394,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Mo-Sa 15:00-22:00; Su 08:00-22:00',
#     'name': 'Drumlin'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3229356, 47.748439]},
#    'properties': {'osm_id': 10755254671,
#     'beds': None,
#     'amenity': None,
#     'shop': 'beauty',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Tangerine'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.323328, 47.7487573]},
#    'properties': {'osm_id': 10270121482,
#     'beds': None,
#     'amenity': None,
#     'shop': 'vacant',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.323021, 47.7487552]},
#    'properties': {'osm_id': 9217377203,
#     'beds': None,
#     'amenity': 'pub',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Ridgecrest Public House'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3022548, 47.7445781]},
#    'properties': {'osm_id': 4227689858,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3079285, 47.7453659]},
#    'properties': {'osm_id': 3729917025,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'picnic_site',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3076371, 47.7453488]},
#    'properties': {'osm_id': 8037692187,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'artwork',
#     'opening_hours': None,
#     'name': 'Dew Beads'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3088393, 47.745803]},
#    'properties': {'osm_id': 4227689832,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'picnic_site',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3770015, 47.7695608]},
#    'properties': {'osm_id': 2975214034,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Best Teriyaki'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.377016, 47.769779]},
#    'properties': {'osm_id': 2975214033,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Full Moon'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3766212, 47.7701712]},
#    'properties': {'osm_id': 2975214133,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Richmond Beach Coffee Co.'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3768143, 47.7694238]},
#    'properties': {'osm_id': 2975214333,
#     'beds': None,
#     'amenity': None,
#     'shop': 'convenience',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': "Seashore's Mini Mart"}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3768686, 47.7694638]},
#    'properties': {'osm_id': 6258115547,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Wake N Bacon BBQ'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3769272, 47.7695085]},
#    'properties': {'osm_id': 2975214334,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Flying Dragon'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.383449, 47.7658686]},
#    'properties': {'osm_id': 1242195728,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'picnic_site',
#     'opening_hours': None,
#     'name': 'Richmond Beach Saltwater Park'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3896867, 47.7692754]},
#    'properties': {'osm_id': 2653215271,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Cabin Tavern'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.3859408, 47.7639544]},
#    'properties': {'osm_id': 10270718873,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'artwork',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1482937, 47.7664348]},
#    'properties': {'osm_id': 6673322624,
#     'beds': None,
#     'amenity': None,
#     'shop': 'wine',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Armstrong Family Winery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1555351, 47.7633299]},
#    'properties': {'osm_id': 7256449986,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'R&L Carriers'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1578203, 47.7589018]},
#    'properties': {'osm_id': 5782062255,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Ryder'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1481688, 47.7628201]},
#    'properties': {'osm_id': 9036788817,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'guest_house',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.155576, 47.7664057]},
#    'properties': {'osm_id': 4223044744,
#     'beds': None,
#     'amenity': None,
#     'shop': 'motorsports',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Ride Motorsports'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1497324, 47.7826704]},
#    'properties': {'osm_id': 4223044747,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Restaurant Depot'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1498029, 47.7648578]},
#    'properties': {'osm_id': 11196816226,
#     'beds': None,
#     'amenity': None,
#     'shop': 'car_repair',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Gerber Collision & Glass'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1467439, 47.7656597]},
#    'properties': {'osm_id': 11196816233,
#     'beds': None,
#     'amenity': None,
#     'shop': 'car_repair',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Group 2 Automotive'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1534046, 47.7645144]},
#    'properties': {'osm_id': 11196821041,
#     'beds': None,
#     'amenity': None,
#     'shop': 'electrical',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Stoneway Electric Supply'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1539281, 47.7658906]},
#    'properties': {'osm_id': 11196821042,
#     'beds': None,
#     'amenity': None,
#     'shop': 'garden_centre',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'SiteOne Landscape Supply'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1572524, 47.769536]},
#    'properties': {'osm_id': 11217116299,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'viewpoint',
#     'opening_hours': None,
#     'name': None}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1500707, 47.7687713]},
#    'properties': {'osm_id': 6673322632,
#     'beds': None,
#     'amenity': None,
#     'shop': 'wine',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'WT Vintners'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2073856, 47.7636273]},
#    'properties': {'osm_id': 6634312958,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Caliber Home Loans'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2011316, 47.7989977]},
#    'properties': {'osm_id': 10571434287,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Barkley Dean Architectural Products'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1082923, 47.7619383]},
#    'properties': {'osm_id': 9484120999,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Woodinville Water District'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.084328, 47.7876944]},
#    'properties': {'osm_id': 743389315,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'picnic_site',
#     'opening_hours': None,
#     'name': 'The Clearing'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1324209, 47.7964475]},
#    'properties': {'osm_id': 11196816227,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Stone Brothers'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1721892, 47.7572275]},
#    'properties': {'osm_id': 4383885834,
#     'beds': None,
#     'amenity': None,
#     'shop': 'car_repair',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Woodinville Sports Car Service'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1820483, 47.7563949]},
#    'properties': {'osm_id': 8177747917,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hardware',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Wine Valley Siding Supply'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.173225, 47.755415]},
#    'properties': {'osm_id': 1226375600,
#     'beds': None,
#     'amenity': None,
#     'shop': 'wine',
#     'rooms': None,
#     'tourism': 'attraction',
#     'opening_hours': None,
#     'name': 'Distefano Winery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1690483, 47.7531228]},
#    'properties': {'osm_id': 994058853,
#     'beds': None,
#     'amenity': 'restaurant',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': 'Tu-Th 16:00-24:00;Fr-Sa 11:00-2:00,Su 11:00-21:00;Mo off',
#     'name': 'Cut Shop'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1734659, 47.7538563]},
#    'properties': {'osm_id': 6033717901,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Vernon Publications'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2566295, 47.7349884]},
#    'properties': {'osm_id': 4499317697,
#     'beds': None,
#     'amenity': None,
#     'shop': None,
#     'rooms': None,
#     'tourism': 'information',
#     'opening_hours': None,
#     'name': 'Park map'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2930971, 47.7333866]},
#    'properties': {'osm_id': 2462453341,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Nasai Teriyaki'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.292837, 47.7333735]},
#    'properties': {'osm_id': 2462453344,
#     'beds': None,
#     'amenity': None,
#     'shop': 'hairdresser',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Golden Hair Salon'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.2919209, 47.7329136]},
#    'properties': {'osm_id': 2462338560,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Starbucks'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.291982, 47.732785]},
#    'properties': {'osm_id': 2100773172,
#     'beds': None,
#     'amenity': 'fast_food',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Heaven Sent Fried Chicken'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.7462718, 47.3404733]},
#    'properties': {'osm_id': 8973148907,
#     'beds': None,
#     'amenity': None,
#     'shop': 'garden_centre',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Sunnycrest Nursery'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.1042267, 47.7722328]},
#    'properties': {'osm_id': 643352343,
#     'beds': None,
#     'amenity': None,
#     'shop': 'kennel',
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Cascade Kennels'}},
#   {'type': 'Feature',
#    'geometry': {'type': 'Point', 'coordinates': [-122.0802794, 47.7545865]},
#    'properties': {'osm_id': 715609140,
#     'beds': None,
#     'amenity': 'cafe',
#     'shop': None,
#     'rooms': None,
#     'tourism': None,
#     'opening_hours': None,
#     'name': 'Common Ground Coffee'}},
#   ...]}
